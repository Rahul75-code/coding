# %%
strs = ["eat","tea","tan","ate","nat","bat"]

# %%
for i in strs:
    st_i = ''.join(sorted(i))
    print(st_i)
# Out:
# ['a', 'e', 't']
# ['a', 'e', 't']
# ['a', 'n', 't']
# ['a', 'e', 't']
# ['a', 'n', 't']
# ['a', 'b', 't']
