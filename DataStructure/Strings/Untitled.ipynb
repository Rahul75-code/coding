# %%
print('Hello')
# Out:
# Hello

# %%
# print(len(haystack))
# print(len(needle))
print(len(haystack)- len(needle))
for i in range(len(haystack) - len(needle)+1):
    print(haystack[i])
#     if haystack[i:i+len(needle)] == needle:
#         return i
# return -1

# %% [markdown]
# 28. Find the Index of the First Occurrence in a String

# %%
haystack ="hello"
needle ="ll"
class Solution:
    def strStr(self, haystack: str, needle: str) -> int:
        
        if needle not in haystack:
            return -1
        else:
            for i in range(len(haystack) -len(needle)+1):
                print(i, haystack[i], haystack[len(needle)], haystack[i:len(needle)], haystack[i:i+len(needle)])
                if haystack[i:i+len(needle)] == needle:
                    return i

# %%
p1 = Solution()
p1.strStr(haystack, needle )

# %%
# s, t ="foo", "bar"
s, t ="egg", "add"
# s = "paper", t = "title"


# s = "badc"
# t = "baba"
match = {}
for i in range(len(s)):
#     print(match[s[i]])
    print(s[i], t[i], match, match.values())
    if s[i] in match and 'd' != match.values() :
        print(i,s[i])
    match[s[i]] = t[i]
print(match)
#         return False

# %%
i = 2
print(s[i])
print(match[s[i]])
print(match.values())
# Out:
# d
# b
# dict_values(['b', 'a', 'b', 'a'])

# %% [markdown]
# Python function that solves the problem — checking if both words in a two‑word string start with the same letter

# %%
def animal_crackers():
    # Take input from user
    text = input("Enter a two-word string: ")

    # Split the string into words
    words = text.split()

    # Check if both words start with the same letter (case-insensitive)
    if len(words) == 2:
        result = words[0][0].lower() == words[1][0].lower()
        print(result)
    else:
        print("Please enter exactly two words.")

# Run the function
animal_crackers()
# Out:
# Please enter exactly two words.

# %%
st_data = sorted(json_data.items(), key = lambda x:x[1], reverse = True)
