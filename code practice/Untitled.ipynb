# %%
list1 = [3,2,4]
target = 6

# %%
sum_dic = {}
for i, val1 in enumerate(list1):
    bal = target - val1
    print(bal)
    if bal in sum_dic:
        print(sum_dic[bal],i)
#         return [sum_dic[bal],i]
    sum_dic[val1] = i
    print(sum_dic)
# Out:
# 3
# {3: 0}
# 4
# {3: 0, 2: 1}
# 2
# 1 2
# {3: 0, 2: 1, 4: 2}

# %%
s = "pwwkew"

# %%
n = len(s)
        ans = 0
        # mp stores the current index of a character
        mp = {}

        i = 0
        # try to extend the range [i, j]
        for j in range(n):
            while s[j] in mp:
                # i = max(mp[s[j]], i)
                # print(' mp[s[j]]=',mp[s[j]],', s[j]=',s[j],', j = ',j,', mp=',mp)
                mp.pop(s[i])
                i += 1
                # print('i=',i)
            # print('i = ',i,', j = ',j,', ans = ',ans)
            ans = max(ans, j - i + 1)
            # print('ans in loop = ',ans)
            mp[s[j]] = j + 1
        return ans
