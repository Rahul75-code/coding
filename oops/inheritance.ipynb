# %%
class Parent:
    x=1
class Child1(Parent):
    pass
class Child2(Parent):
    pass
class Child3(Parent):
    pass

# %%
Child1.x = 2
Child2.x = 3
# Child3.x = 4
Parent.x = 8
print(Parent.x, Child1.x, Child2.x, Child3.x)
# Out:
# 8 2 3 8
